# %%
from bitmex_websocket import BitMEXWebsocket

# Place your API ID and Secret
API_KEY = ''
API_KEY_SECRET = ''


ws = BitMEXWebsocket(endpoint="https://testnet.bitmex.com/api/v1", symbol="XBTUSD", api_key=API_KEY, api_secret=API_KEY_SECRET)

# %%
ws.market_depth()
# Out:
# [{'symbol': 'XBTUSD',
#   'id': 15500000000,
#   'side': 'Sell',
#   'size': 5,
#   'price': 1000000},
#  {'symbol': 'XBTUSD',
#   'id': 15500000100,
#   'side': 'Sell',
#   'size': 100003,
#   'price': 999999},
#  {'symbol': 'XBTUSD',
#   'id': 15502119900,
#   'side': 'Sell',
#   'size': 5000,
#   'price': 978801},
#  {'symbol': 'XBTUSD',
#   'id': 15504648350,
#   'side': 'Sell',
#   'size': 2191000,
#   'price': 953516.5},
#  {'symbol': 'XBTUSD',
#   'id': 15515440800,
#   'side': 'Sell',
#   'size': 300,
#   'price': 845592},
#  {'symbol': 'XBTUSD',
#   'id': 15520000000,
#   'side': 'Sell',
#   'size': 1000,
#   'price': 800000},
#  {'symbol': 'XBTUSD',
#   'id': 15520979900,
#   'side': 'Sell',
#   'size': 100,
#   'price': 790201},
#  {'symbol': 'XBTUSD',
#   'id': 15530999500,
#   'side': 'Sell',
#   'size': 1000,
#   'price': 690005},
#  {'symbol': 'XBTUSD',
#   'id': 15538800000,
#   'side': 'Sell',
#   'size': 80,
#   'price': 612000},
#  {'symbol': 'XBTUSD',
# ...

# %%
ws.get_instrument()
# Out:
# {'symbol': 'XBTUSD',
#  'rootSymbol': 'XBT',
#  'state': 'Open',
#  'typ': 'FFWCSX',
#  'listing': '2016-05-04T12:00:00.000Z',
#  'front': '2016-05-04T12:00:00.000Z',
#  'expiry': None,
#  'settle': None,
#  'relistInterval': None,
#  'inverseLeg': '',
#  'sellLeg': '',
#  'buyLeg': '',
#  'optionStrikePcnt': None,
#  'optionStrikeRound': None,
#  'optionStrikePrice': None,
#  'optionMultiplier': None,
#  'positionCurrency': 'USD',
#  'underlying': 'XBT',
#  'quoteCurrency': 'USD',
#  'underlyingSymbol': 'XBT=',
#  'reference': 'BMEX',
#  'referenceSymbol': '.BXBT',
#  'calcInterval': None,
#  'publishInterval': None,
#  'publishTime': None,
#  'maxOrderQty': 10000000,
#  'maxPrice': 1000000,
#  'lotSize': 1,
#  'tickSize': 0.5,
#  'multiplier': -100000000,
#  'settlCurrency': 'XBt',
#  'underlyingToPositionMultiplier': None,
#  'underlyingToSettleMultiplier': -100000000,
#  'quoteToSettleMultiplier': None,
#  'isQuanto': False,
#  'isInverse': True,
#  'initMargin': 0.01,
# ...

# %%
ws.funds()
# Out:
# {'account': 268514,
#  'currency': 'XBt',
#  'riskLimit': 1000000000000,
#  'prevState': '',
#  'state': '',
#  'action': '',
#  'amount': 1000000,
#  'pendingCredit': 0,
#  'pendingDebit': 0,
#  'confirmedDebit': 0,
#  'prevRealisedPnl': 0,
#  'prevUnrealisedPnl': 0,
#  'grossComm': 0,
#  'grossOpenCost': 0,
#  'grossOpenPremium': 0,
#  'grossExecCost': 0,
#  'grossMarkValue': 0,
#  'riskValue': 0,
#  'taxableMargin': 0,
#  'initMargin': 0,
#  'maintMargin': 0,
#  'sessionMargin': 0,
#  'targetExcessMargin': 0,
#  'varMargin': 0,
#  'realisedPnl': 0,
#  'unrealisedPnl': 0,
#  'indicativeTax': 0,
#  'unrealisedProfit': 0,
#  'syntheticMargin': None,
#  'walletBalance': 1000000,
#  'marginBalance': 1000000,
#  'marginBalancePcnt': 1,
#  'marginLeverage': 0,
#  'marginUsedPcnt': 0,
#  'excessMargin': 1000000,
#  'excessMarginPcnt': 1,
#  'availableMargin': 1000000,
#  'withdrawableMargin': 1000000,
#  'timestamp': '2019-12-30T14:17:36.821Z',
#  'grossLastValue': 0,
# ...

# %%
ws.recent_trades()
# Out:
# [{'timestamp': '2019-12-30T15:56:10.671Z',
#   'symbol': 'XBTUSD',
#   'side': 'Buy',
#   'size': 10,
#   'price': 7178.5,
#   'tickDirection': 'PlusTick',
#   'trdMatchID': '8ef8789a-dd8b-6260-5467-55ffaa683bc0',
#   'grossValue': 139300,
#   'homeNotional': 0.001393,
#   'foreignNotional': 10},
#  {'timestamp': '2019-12-30T15:56:15.941Z',
#   'symbol': 'XBTUSD',
#   'side': 'Sell',
#   'size': 25,
#   'price': 7178,
#   'tickDirection': 'MinusTick',
#   'trdMatchID': '44741fa8-a8ee-2e66-6ea4-b427ecb778c2',
#   'grossValue': 348275,
#   'homeNotional': 0.00348275,
#   'foreignNotional': 25},
#  {'timestamp': '2019-12-30T15:56:16.702Z',
#   'symbol': 'XBTUSD',
#   'side': 'Sell',
#   'size': 455,
#   'price': 7178,
#   'tickDirection': 'ZeroMinusTick',
#   'trdMatchID': '012cc92c-2019-a0e5-16a6-e347c6f1a3ad',
#   'grossValue': 6338605,
#   'homeNotional': 0.06338605,
#   'foreignNotional': 455},
#  {'timestamp': '2019-12-30T15:56:16.702Z',
#   'symbol': 'XBTUSD',
#   'side': 'Sell',
# ...

# %%
ws.get_ticker()
# Out:
# {'last': 7172.0, 'buy': 7172.0, 'sell': 7172.0, 'mid': 7172.0}
